# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mplt
import numpy as np
from operator import itemgetter
df = pd.read_excel('lianjia-11-15.xlsx')
df2 = pd.read_excel('[20171201]海淀租房.xlsx')
# %matplotlib inline

# %%
coldir = {
    '列-1':'title',
    '列-1-链接':'title-href',
    '列-2':'rent',
    '列-3':'community',
    '列-3-链接':'add-href',
    '列-4':'type',
    '列-5':'area',
    '列-6':'toward',
    '列-7':'address',
    '列-8':'subway',
    '列-9':'count',
}
def replace_zufang(value):
    value = value.replace('租房','')
    return value.replace('租房','')
def replace_pingmi(value):
    value = value.replace('平米','')
    return value.replace('平米','')
def fomateDf(data):
    df = data
    df.rename(columns = coldir ,inplace = True)
    df.drop(['列-7-链接','来源网址','add-href'],axis = 1,inplace=True)
    df['address'] = df['address'].apply(replace_zufang)
    df['area'] = df['area'].apply(replace_pingmi)
    return df

# %%
df = fomateDf(df)
df2 = fomateDf(df2)

# %%
# df[df['community'] == '']
df
# Out:
#                              title  \
# 0          富力桃园C区东北向精装修两居室，主卧带大飘窗。
# 1               南北通透三居 两卫 中间楼层 不临街
# 2        普惠南里精装修一居室，带客厅，西三环，公主坟商圈。
# 3                  永泰西里 2室1厅 4800元
# 4                当代城市家园 1室1厅 5300元
# 5                南北通透三居室 随时看房 随时入住
# 6               南北通透精装大三居 带电梯 随时入住
# 7      国兴家园 南北通透 电梯直达拎包入住 带车位 白石桥南
# 8     牡丹园  塔院 北太平庄 马甸出门是10号地铁 看房随时
# 9              精装修 两居室 翠为中里 随时可以入住
# 10     知春路地铁10号线13号线罗庄西里精装1居室价格可商量
# 11       玉海园二里 精装两居 南北通透  采光好 看房随时
# 12              花园桥 北洼路 中海雅园 两居室整租
# 13             北坞嘉园 精装两居  带阁楼 看房方便
# 14         知春路地铁 北航南门 精装两居套间 可做大一居
# 15         上地东里一居，精装，家具齐全，随时可入住。安静
# 16             富力桃园A区精装南北通透双卫电梯两居室
# 17                 逸成东苑 2室1厅 7500元
# 18           百旺新城  秋露园整租两居 距离16号线近
# 19               牡丹园马甸冠城南园大三居精装临地铁
# 20                牡丹园东里 2室1厅 7000元
# 21               翠微南里财政部塔楼电梯 朝南一居室
# 22        中关村 苏州街 海淀黄庄 一家人两居室 可长租.
# 23              六里桥 澐澐国际 温馨两居 户型方正
# 24          甘家口 增光路40号院 高楼层两居室 精装修
# 25        志强南园小西天文慧园积水潭地铁2号线南北向两居室
# 26               清上园精装两居，价格可谈，随时看房
# 27     北洼路32号 中国人民银行宿舍 北洼路玲珑路交叉口电梯
# 28             交大东路56号院 2室1厅 7000元
# 29              蓟门桥 精装修两居室 近北影政法大学
# ...                            ...
# 3000       精装东向方正一居加书房，稳定长租，地铁13号线
# 3001      晶都国际 颐堤港 将台 精装修 酒仙桥 华信医院
# 3002          首开常青藤/中间位置/明厨明卫，看房方便
# 3003            茉藜园精装大两居 看房随时 随时签约
# 3004       富力桃园C区东北向精装修两居室，主卧带大飘窗。
# 3005        角门西双地铁 干净整洁两居室  业主诚心出租
# 3006                华贸城 2室1厅 6300元
# 3007              风景线3居  视野好  楼层适中
# 3008             茉藜园正规一居室 精装修 随时签约
# 3009              角门西精装一间 拎包入住 位置佳
# 3010  华贸城67平东向一居室 随时看房 拎包入住 地铁13号线
# 5     115    南 北     西三旗               随时看房     22
# 6     114    南 北     西三旗               随时看房     23
# 7     148    南 北     甘家口     距离6号线白石桥南站284米     54
# 8      57    南 北      马甸               随时看房     20
# 9      39    南 西     公主坟     距离1号线万寿路站1045米     18
# 10     46      南     知春路               随时看房     23
# 11     71    南 北     玉泉路               随时看房     17
# 12    102     西南     紫竹桥               随时看房     20
# 13     83      南     颐和园               随时看房     21
# 14     60      南     知春路               随时看房     17
# 15     45   东 西南      上地               随时看房     37
# 16     91    南 北     西三旗               随时看房     19
# 17     75     东南     学院路               随时看房     16
# 18     76    南 北     西北旺               随时看房     20
# 19    146      南      马甸     距离10号线牡丹园站623米     14
# 20     75    南 北     牡丹园     距离10号线牡丹园站623米     42
# 21     44      南     公主坟     距离1号线万寿路站1045米     31
# 22     55     东北     苏州桥               随时看房     22
# 23    104     东北     六里桥               随时看房     31
# 24     77    南 北     甘家口     距离6号线白石桥南站284米     91
# 25     57    南 北     新街口               随时看房     36
# 26     60      南     安宁庄               随时看房     23
# 27     71      西     紫竹桥               随时看房     33
# 28     50      东     西直门               随时看房     29
# 29     57    南 北     知春路     距离10号线西土城站707米     25
# ...   ...    ...     ...                ...    ...
# 3000   52      东      北苑      距离13号线北苑站623米     21
# 3001   49     东南     酒仙桥  距离14号线(东段)将台站795米     26
# 3002   92    南 北      东坝               随时看房     50
# 3003  109     东南      北苑     距离5号线立水桥南站232米     77
# 3004   88     东北     西三旗               随时看房     47
# 3005  103    南 北     马家堡               随时看房     36
# 3006   52      西      北苑      距离13号线北苑站623米     14
# 3007  136     西南     酒仙桥  距离14号线(东段)将台站795米     29
# 3008   67     西南      北苑               随时看房     40
# 3009   42      东      草桥     距离10号线草桥站1027米     31
# 3010   66      东      北苑      距离13号线北苑站623米     46
# 3011   64      南     酒仙桥  距离14号线(东段)将台站795米     37
# 3012   50      南     酒仙桥               随时看房     12
# 3013  122    南 北      草桥      距离4号线角门西站835米      1
# 3014   71      南     酒仙桥               随时看房     31
# 3015   67    南 北      草桥      距离4号线角门西站835米     27
# 3016   74      南     酒仙桥               随时看房     10
# 3017  130    南 北     西三旗               随时看房     22
# 3018  135    南 北      北苑      距离13号线北苑站623米     32
# 3019   51    南 北      草桥     距离4号线马家堡站1132米     16
# 3020   42      北     马家堡     距离4号线公益西桥站456米     19
# 3021   55      南      北苑      距离13号线北苑站623米     15
# 3022  119     东南     马家堡     距离4号线公益西桥站456米      4
# 3023   84    南 北      北苑               随时看房     27
# 3024   38     西北      草桥      距离4号线角门西站835米      9
# 3025   64    南 北      草桥     距离10号线草桥站1027米     38
# 3026  299    南 北      北苑               随时看房     12
# 3027   59      东      北苑     距离5号线立水桥南站232米     29
# 3028   45     西南     酒仙桥               随时看房     32
# 3029   81      南      北苑               随时看房     11
#
# [3030 rows x 10 columns]

# %%
def drawCountPlt(data,name):
    pd.value_counts(data['address']).plot.bar(
        figsize=(20,5),
        rot=45,
        fontsize=18,
        title=(name + '房源数量')
    )

# %%
drawCountPlt(df,'11-10')

# %%
drawCountPlt(df2,'12-01')

# %%
def getPerAreaRent(df):
    value = set( df['address'].values.tolist() )
    rent_list = []
    for item in value:
        flag = (df['address'] == item)
        rent = df[flag]['rent'].astype(int)
        area = df[flag]['area'].astype(int)
        rent_list.append({
            'value':round(rent.mean() / area.mean(),2), 
            'name':item
        })
    rent_mean_list = sorted(rent_list,key = itemgetter('value'),reverse = True)
    return rent_mean_list

# %%
df1list = getPerAreaRent(df)
df1list
# Out:
# [{'name': '西山', 'value': 141.9},
#  {'name': '知春路', 'value': 141.15},
#  {'name': '魏公村', 'value': 139.53},
#  {'name': '中关村', 'value': 136.3},
#  {'name': '五道口', 'value': 134.26},
#  {'name': '公主坟', 'value': 133.54},
#  {'name': '苏州桥', 'value': 132.27},
#  {'name': '甘家口', 'value': 130.33},
#  {'name': '万柳', 'value': 129.32},
#  {'name': '二里庄', 'value': 128.58},
#  {'name': '西直门', 'value': 127.8},
#  {'name': '牡丹园', 'value': 127.62},
#  {'name': '皂君庙', 'value': 126.89},
#  {'name': '四季青', 'value': 126.48},
#  {'name': '北太平庄', 'value': 126.38},
#  {'name': '双榆树', 'value': 126.0},
#  {'name': '厂洼', 'value': 124.54},
#  {'name': '马甸', 'value': 124.43},
#  {'name': '海淀其它', 'value': 123.73},
#  {'name': '新街口', 'value': 120.4},
#  {'name': '圆明园', 'value': 119.78},
#  {'name': '白石桥', 'value': 119.12},
#  {'name': '军博', 'value': 117.17},
#  {'name': '上地', 'value': 116.62},
#  {'name': '紫竹桥', 'value': 116.26},
#  {'name': '小西天', 'value': 116.15},
#  {'name': '马连洼', 'value': 111.83},
#  {'name': '世纪城', 'value': 106.75},
#  {'name': '五棵松', 'value': 106.69},
#  {'name': '定慧寺', 'value': 105.13},
#  {'name': '西北旺', 'value': 104.94},
#  {'name': '万寿路', 'value': 104.73},
#  {'name': '清河', 'value': 104.43},
#  {'name': '学院路', 'value': 100.84},
#  {'name': '西二旗', 'value': 100.66},
#  {'name': '酒仙桥', 'value': 99.39},
#  {'name': '田村', 'value': 95.4},
#  {'name': '玉泉路', 'value': 94.7},
#  {'name': '颐和园', 'value': 94.11},
#  {'name': '北苑', 'value': 92.26},
#  {'name': '六里桥', 'value': 92.0},
#  {'name': '安宁庄', 'value': 83.79},
#  {'name': '草桥', 'value': 78.26},
#  {'name': '西三旗', 'value': 78.04},
#  {'name': '马家堡', 'value': 75.76},
#  {'name': '东坝', 'value': 72.83},
#  {'name': '杨庄', 'value': 67.72},
#  {'name': '海淀北部新区', 'value': 67.41}]

# %%
df2list = getPerAreaRent(df2)
df2list
# Out:
# [{'name': '魏公村', 'value': 145.63},
#  {'name': '西山', 'value': 141.52},
#  {'name': '万柳', 'value': 136.47},
#  {'name': '二里庄', 'value': 136.38},
#  {'name': '五道口', 'value': 135.68},
#  {'name': '甘家口', 'value': 134.51},
#  {'name': '公主坟', 'value': 133.88},
#  {'name': '中关村', 'value': 133.65},
#  {'name': '知春路', 'value': 132.57},
#  {'name': '皂君庙', 'value': 130.68},
#  {'name': '苏州桥', 'value': 129.52},
#  {'name': '圆明园', 'value': 126.59},
#  {'name': '双榆树', 'value': 125.23},
#  {'name': '白石桥', 'value': 123.79},
#  {'name': '马甸', 'value': 122.37},
#  {'name': '西直门', 'value': 122.06},
#  {'name': '小西天', 'value': 120.73},
#  {'name': '四季青', 'value': 120.1},
#  {'name': '定慧寺', 'value': 118.63},
#  {'name': '北太平庄', 'value': 118.27},
#  {'name': '紫竹桥', 'value': 117.97},
#  {'name': '牡丹园', 'value': 116.78},
#  {'name': '厂洼', 'value': 114.15},
#  {'name': '军博', 'value': 113.91},
#  {'name': '新街口', 'value': 111.69},
#  {'name': '学院路', 'value': 110.8},
#  {'name': '世纪城', 'value': 108.36},
#  {'name': '五棵松', 'value': 105.27},
#  {'name': '万寿路', 'value': 104.95},
#  {'name': '上地', 'value': 101.55},
#  {'name': '西北旺', 'value': 99.4},
#  {'name': '玉泉路', 'value': 96.92},
#  {'name': '海淀其它', 'value': 96.39},
#  {'name': '清河', 'value': 96.32},
#  {'name': '西二旗', 'value': 95.22},
#  {'name': '马连洼', 'value': 90.98},
#  {'name': '田村', 'value': 89.96},
#  {'name': '颐和园', 'value': 88.98},
#  {'name': '安宁庄', 'value': 87.6},
#  {'name': '六里桥', 'value': 85.4},
#  {'name': '西三旗', 'value': 83.03},
#  {'name': '海淀北部新区', 'value': 69.21},
#  {'name': '杨庄', 'value': 68.75}]

# %%
def getDir(arr):
    rs = {}
    for i in arr:
        name = i['name']
        val = i['value']
        rs[name] = val;
    return rs;

def getBoth(list1,list2):
    rs1 = {
        'name':[],
        'value':[]
    }
    rs2 = {
        'name':[],
        'value':[]
    }
    dir1 = getDir(list1)
    dir2 = getDir(list2)
    
    list2_name = [i['name'] for i in list2]
    for item in list1:
        iname = item['name']
#         如果某项1、2list都有则加入对比表
        if(iname in list2_name):
            rs1['name'].append(iname)
            rs1['value'].append(dir1[iname])
            rs2['value'].append(dir2[iname])
        
    rs2['name'] = rs1['name']
    return rs1,rs2
    
df1plot,df2plot = getBoth(df1list[:],df2list[:])
fig, ax = plt.subplots(figsize = (40,5))
def drawPlot(df1plot,df2plot,title):
    bar_width = 0.5
    x_index = np.arange(0,len(df1plot['name']) * 1.8,1.8)
    # print(x_index)
    x_index_width = 0.5
    ax.bar(x_index,df1plot['value'],bar_width)
    ax.bar(x_index + 0.8,df2plot['value'],bar_width)

    for x,y in zip(x_index,df1plot['value']):
        plt.text(x+0.3, y+0.05, '%.2f' % y, ha='center', va= 'bottom')

    for x,y in zip(x_index,df2plot['value']):
        plt.text(x+0.6, y+0.05, '%.2f' % y, ha='center', va= 'bottom')

    ax.set_title(title)
    plt.yticks(fontsize = 18)
    plt.xticks(x_index + x_index_width * 0.5, df1plot['name'],fontsize = 18,rotation = 40)
    plt.show()
drawPlot(df1plot,df2plot,'每平米价格')

# %%
def getPerCommunity(df,address):
    supFlag = df['address'] == address
    value = set( df[supFlag]['community'].values.tolist() )
    
    rent_list = []
    for item in value:
        flag = (df['community'] == item)
        rent = df[flag]['rent'].astype(int)
        area = df[flag]['area'].astype(int)
        rent_list.append({
            'value':round(rent.mean() / area.mean(),2), 
            'name':item
        })
    rent_mean_list = sorted(rent_list,key = itemgetter('value'),reverse = True)
    return rent_mean_list

# %%
add = '西北旺'
# def drawCom(address):
df1comlist = getPerCommunity(df,address)
df2comlist = getPerCommunity(df2,address)

fig, ax = plt.subplots(figsize = (20,5))
df1complot,df2complot = getBoth(df1comlist,df2comlist)
drawPlot(df1complot,df2complot,address+'各小区每平米价格')

# %%
# addList = set( df['address'].values.tolist() )

# %%
# for i in addList.tolist():
#     addList(i)
